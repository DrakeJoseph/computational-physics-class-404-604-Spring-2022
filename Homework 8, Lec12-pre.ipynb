# %%
# Lec12 Homework 8
# Drake Joseph

#Any mass can lead to a gravitational potential in 3-D (x-y-z) space
#We will set G=1 for this problem.
#Please solve the potential of a line mass (i.e. one zone at x=50, y=50 with 
#nonzero density and all others with zero density) using Gauss-Siedel method. 
#Since the problem has symmetry in the Z direction:

#Guass-Siedel method
#--------------------------------------------------------------------------------------------#
# First, we can complete the example from the textbook below:

""" From "COMPUTATIONAL PHYSICS", 3rd Ed, Enlarged Python eTextBook  
    by RH Landau, MJ Paez, and CC Bordeianu
    Copyright Wiley-VCH Verlag GmbH & Co. KGaA, Berlin;  Copyright R Landau,
    Oregon State Unv, MJ Paez, Univ Antioquia, C Bordeianu, Univ Bucharest, 2015.
    Support by National Science Foundation"""
   
# LaplaceLine.py:  Solve Laplace's eqtn, 3D matplot, close shell to quit

import matplotlib.pylab as p;
from mpl_toolkits.mplot3d import Axes3D
from numpy import *;
import numpy as np;
print("Initializing")
Nmax = 100; Niter = 5000; V = zeros((Nmax, Nmax), float); rho = zeros((Nmax, Nmax), float) #Initial parameters
rho[50,50]=1
    
for iter in range(Niter):                                  
    if iter%10 == 0: print(iter)
    maxerr=0.
    for i in range(1, Nmax-1):                                                
        for j in range(1,Nmax-1): 
            du = 1./4.*(V[i+1,j]+V[i-1,j]+V[i,j+1]+V[i,j-1])-V[i,j]-4*np.pi*rho[i,j]
            if(maxerr<abs(du)): # how much correction we have in this step
                maxerr=abs(du)
            V[i,j]= V[i,j] + du# please finish this line for Gauss-Siedel method
    print(maxerr)
    if(maxerr<1.e-3):
        break
            
x = range(0, Nmax, 1)
y = range(0, Nmax, 1)                              
X, Y = p.meshgrid(x,y)                 

def functz(V):                                         # V(x, y) 
    z = V[X,Y]                        
    return z

Z = functz(V)                          
fig = p.figure()                                      # Create figure
ax = Axes3D(fig)                                      # Plot axes
ax.plot_wireframe(X, Y, Z, color = 'r')               # Red wireframe
ax.set_xlabel('X')                                     
ax.set_ylabel('Y')
ax.set_zlabel('Potential')
p.show()                                              # Show fig


#The domain is X from 0 to 100, Y from 0 to 100. x= y=1. (assume  at the boundary and  is always 1)
#Please verify that the potential has radial dependence close to 2G*ln(r)+constant.
#Where  is its mass per unit length and r is the distance to the line mass.
# Out:
# Initializing
# 0
# 12.566370614359172
# 3.141592653589793
# 1.7671458676442597
# 1.2271846303085132
# 0.9395632325799568
# 0.7610462183897653
# 0.6394902251747316
# 0.551397183951682
# 0.4846264312075341
# 0.4322748105523999
# 10
# 0.39012801652354057
# 0.35546788282413644
# 0.32646269099647185
# 0.30183310927928275
# 0.2806585926844338
# 0.26225986271956714
# 0.24612473444678074
# 0.23185971956102414
# 0.21915752813445444
# 0.2077746925319044
# 20
# 0.19751581708814214
# 0.18822227240655565
# 0.17976393681803948
# 0.17203306807964402
# 0.1649396907065679
# 0.1584080789545883
# 0.15237404340269478
# 0.1467828147867536
# 0.14158737714602232
# 0.136747142790556
# 30
# 0.13222689001497834
# 0.12799590472053524
# 0.12402728169819355
# 0.12029735196852087
# 0.11678521042099632
# 0.11347232383966599
# 0.11034220379547577
# 0.10738013221805787
# 0.10457293000806445
# 0.10190876101541946
# 40
# 0.09937696523394379
# 0.09696791625519019
# 0.09467289896287134
# 0.09248400419236447
# ...

# %%
# Please verify that the potential has radial dependence close to 2G*ln(r)+constant. 
# Where  is its mass per unit length and r is the distance to the line mass.

import matplotlib.pyplot as plt
r=np.sqrt((50-X)**2+(50-Y)**2) # r is the distance to the line mass.
R=np.log(r)                      
fig = p.figure()                                      
ax = Axes3D(fig)                                      
ax.plot_wireframe(X, Y, R, color = 'r')
plt.show()
# Out:
# C:\Users\drake\AppData\Local\Temp/ipykernel_20896/1712407301.py:6: RuntimeWarning: divide by zero encountered in log
#   R=np.log(r)
# C:\Users\drake\AppData\Local\Temp/ipykernel_20896/1712407301.py:8: MatplotlibDeprecationWarning: Axes3D(fig) adding itself to the figure is deprecated since 3.4. Pass the keyword argument auto_add_to_figure=False and use fig.add_axes(ax) to suppress this warning. The default value of auto_add_to_figure will change to False in mpl3.5 and True values will no longer work in 3.6.  This is consistent with other Axes classes.
#   ax = Axes3D(fig)

# %%
# This plot has a shape similar to our previous solution. Therefore, the potential has a radial dependence.
