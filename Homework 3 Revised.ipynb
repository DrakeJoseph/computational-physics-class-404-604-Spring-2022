# %%
#1) Calculate and plot the ratio F(n)/F(n-1) with respect to n using memorization method.

print("Problem #1")

# Memorization Method, taken from lecture notes
# if we have defined an array table = [None]*(n+1)

def fib3(n, table): # Store the data we already calculated, linear space and time complexity, but still have the stack limit
    if n == 0 or n==1:
        table[n]=n
#Note: I get an error if fib3 = Nonetype... Must make a case for this here...
    if table[n] is None:
        table[n] = fib3(n-1,table)+fib3(n-2,table)
        
    return table[n]
        
import time
n=10
table = [None]*(n+1)
fib3(n,table)

Fibratio=[] #Empty array for storing the values of the ratio
for i in range(2,n+1):
    ratio=table[i]/table[i-1]
    Fibratio=np.append(Fibratio,ratio)

plt.plot(np.arange(2,n+1), Fibratio)
plt.xlabel('n')
plt.ylabel('F(n)/F(n-1)')
plt.show()
# Out:
# Problem #1

# %%
#2)

#a) Use the Recursion method, Tabulation method,  and matrix method to calculate the time spent for different n (e.g. 1, 10, 100, 1000, 10000, … uniform in the log space). (caution: recursion method will break when n>100)

# Recursion method fib2, taken form lecture notes
import time
import matplotlib.pylab as plt
import numpy as np
import math

print("")
print("Problem #2")
print("Recursion Method part a")

#initialize log file to write within
logw = open('./hw2_time_log.txt','a')

# Recursion method fib2, taken form lecture notes
def fib_r(n):   
    if n == 0: return 0
    elif n == 1: return 1
    else: return fib2(n-1)+fib2(n-2)
    
# Tabulation method fib2, taken form lecture notes
def fib_t(n):
    table=[0]*(n+1)
    table[1] = 1
    for i in range(2,n+1):
        table[i]=  table[i-1]+table[i-2]        
    return table[n]

# Matrix method fib2, taken form lecture notes
def arrpow(arr, n):
    yarr=arr
    if n<1:
        print('n needs to be larger than 1')
    if n==1:
        return arr
    yarr = arrpow(arr, n//2)
    yarr = [[yarr[0][0]*yarr[0][0]+yarr[0][1]*yarr[1][0],yarr[0][0]*yarr[0][1]+yarr[0][1]*yarr[1][1]],
            [yarr[1][0]*yarr[0][0]+yarr[1][1]*yarr[1][0],yarr[1][0]*yarr[0][1]+yarr[1][1]*yarr[1][1]]]
    if n%2:
        yarr=[[yarr[0][0]*arr[0][0]+yarr[0][1]*arr[1][0],yarr[0][0]*arr[0][1]+yarr[0][1]*arr[1][1]],
            [yarr[1][0]*arr[0][0]+yarr[1][1]*arr[1][0],yarr[1][0]*arr[0][1]+yarr[1][1]*arr[1][1]]]
    return yarr

def fib_matrix(n):
    arr= [[1,1],[1,0]]
    f=arrpow(arr,n-1)[0][0]
    return f
# Out:
# Problem #2
# Recursion Method part a
# 1
# --- 0.0 seconds for n=1 ---
# 55
# --- 0.0 seconds for n=10 ---
# 832040
# --- 1.0660433769226074 seconds for n=30 ---
#
# Tabulation Method part a
# 1
# --- 1.0660433769226074 seconds n = 1 ---
# 0
# --- 0.005090951919555664 seconds n = 10 ---
# 0
# --- 0.0 seconds n = 100 ---
# 0
# --- 0.0 seconds n = 1000 ---
# 0
# --- 0.0 seconds n = 10000 ---
#
# Matrix Method part a
# --- 0.0 seconds ---
# --- 0.0 seconds n = 10000 ---
# Now the file has more content!Now the file has more content!Now the file has more content!Now the file has more content!Now the file has more content!Now the file has more content!
# 1 0.0
# 4 0.0
# 7 0.0
# 10 0.0
# 13 0.0
# 16 0.0041048526763916016
# 19 0.019857406616210938
# 22 0.08084511756896973
# 25 0.3134036064147949
# 28 1.3502280712127686
# 31 5.752583980560303
# 34 23.422550916671753
# 37 100.55987238883972
# 40 421.3441593647003
# 100 0.0
# 200 0.0
# 300 0.0
# 400 0.0
# 500 0.0
# 600 0.0
# 700 0.0
# 800 0.0
# ...
